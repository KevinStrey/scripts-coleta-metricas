# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', 30)

# %%
evometrics_df = pd.read_csv("results/evometrics.csv")
# Out:
# /tmp/ipykernel_297888/1288837588.py:1: DtypeWarning: Columns (0: commitprevious) have mixed types. Specify dtype option on import or set low_memory=False.
#   evometrics_df = pd.read_csv("results/evometrics.csv")

# %%
evometrics_df[['file', 'method']].head()
# Out:
#                                                                                file  \
# 0    repo1/native/org.eclipse.cdt.native.serial/src/org/eclipse/cdt/serial/StopBits
# 1    repo1/native/org.eclipse.cdt.native.serial/src/org/eclipse/cdt/serial/StopBits
# 2    repo1/native/org.eclipse.cdt.native.serial/src/org/eclipse/cdt/serial/StopBits
# 3    repo1/native/org.eclipse.cdt.native.serial/src/org/eclipse/cdt/serial/StopBits
# 4  repo1/native/org.eclipse.cdt.native.serial/src/org/eclipse/cdt/serial/SerialPort
#
#                      method
# 0              getStrings()
# 1      fromStringIndex(int)
# 2  getStringIndex(StopBits)
# 3              getDefault()
# 4         getOutputStream()

# %%
evometrics_df[evometrics_df['method'] == 'getSkipBuild()']
# Out:
#        project                                    commit  \
# 16690      cdt  96ef6bcb785619cb23e2aad86dd44a207177b5bb
# 150002     cdt  ab4138f805ebc028b6ed5008d506cab4e2232272
# 231950     cdt  0bd96c77efa3d6b5ebbad2d161ca02fe467f8969
# 313898     cdt  0c257b0bbdb183f02cf0845a916cea2e628bfd95
# 395846     cdt  e3e551cfc8c3e990487c299b01184d0cf762d092
# 477794     cdt  7f494ba11204b87606f5e164fe3785ba5a63cda7
#
#                                   commitprevious  release  \
# 16690                                        NaN        1
# 150002  96ef6bcb785619cb23e2aad86dd44a207177b5bb        2
# 231950  ab4138f805ebc028b6ed5008d506cab4e2232272        3
# 313898  0bd96c77efa3d6b5ebbad2d161ca02fe467f8969        4
# 395846  0c257b0bbdb183f02cf0845a916cea2e628bfd95        5
# 477794  e3e551cfc8c3e990487c299b01184d0cf762d092        6
#
#                                                                                                                       file  \
# 16690   repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
# 150002  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
# 231950  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
# 313898  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
# 395846  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
# 477794  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
#
#                 method  BOM  TACH  FCH  LCH  CHO  FRCH       CHD     WCH  \
# 16690   getSkipBuild()    1     0    0    0    0     0  0.000000   0.000
# 150002  getSkipBuild()    1    10    2    2    1     1  0.263158  10.000
# 231950  getSkipBuild()    1     0    2    2    0     1  0.000000   5.000
# 313898  getSkipBuild()    1     4    2    4    1     2  0.117647   2.500
# 395846  getSkipBuild()    1     0    2    4    0     2  0.000000   5.250
# 477794  getSkipBuild()    1     0    2    4    0     2  0.000000   2.625
#
#              WCD  WFR  ATAF  LCA       LCD  CSB      CSBS      ACDF
# 16690   0.000000    0   0.0    0  0.000000    0  0.000000  0.000000
# 150002  0.263158    1  10.0   10  0.263158   10  0.333333  0.263158
# 231950  0.131579    1   0.0   10  0.263158   10  0.333333  0.263158
# 313898  0.065789    4   2.0    4  0.117647   14  0.466667  0.190402
# 395846  0.150542    4   0.0    4  0.117647   14  0.466667  0.190402
# 477794  0.075271    4   0.0    4  0.117647   14  0.466667  0.190402

# %%
evometrics_df[evometrics_df['method'] == 'setupSkipBuild()']
# Out:
#        project                                    commit  \
# 491690     cdt  2d87281d09f9dbc872d4652e578ceaebf483a27e
# 608293     cdt  9e17fbca4ff08df9a0895f0991d2e8d165468376
# 690245     cdt  909e2294b144c32f5783ae5071a8b54c7a03ba44
# 772200     cdt  3447d2a00a7767620d12a9b8ae478e88f446caac
# 854155     cdt  452d57aa7aa1bd4dee015f245a0e681aaaf600d5
# 936110     cdt  01ae52986483dbc6d42c59e0e10730a8aadd4467
#
#                                   commitprevious  release  \
# 491690  7f494ba11204b87606f5e164fe3785ba5a63cda7        7
# 608293  2d87281d09f9dbc872d4652e578ceaebf483a27e        8
# 690245  9e17fbca4ff08df9a0895f0991d2e8d165468376        9
# 772200  909e2294b144c32f5783ae5071a8b54c7a03ba44       10
# 854155  3447d2a00a7767620d12a9b8ae478e88f446caac       11
# 936110  452d57aa7aa1bd4dee015f245a0e681aaaf600d5       12
#
#                                                                                                                       file  \
# 491690  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
# 608293  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
# 690245  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
# 772200  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
# 854155  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
# 936110  repo1/toolchains/arduino/org.eclipse.cdt.arduino.core.tests/src/org/eclipse/cdt/arduino/core/tests/FullIntegration
#
#                   method  BOM  TACH  FCH  LCH  CHO  FRCH       CHD   WCH  \
# 491690  setupSkipBuild()    7     0    0    0    0     0  0.000000   0.0
# 608293  setupSkipBuild()    7     0    0    0    0     0  0.000000   0.0
# 690245  setupSkipBuild()    7     0    0    0    0     0  0.000000   0.0
# 772200  setupSkipBuild()    7     0    0    0    0     0  0.000000   0.0
# 854155  setupSkipBuild()    7    12   11   11    1     1  1.333333   0.0
# 936110  setupSkipBuild()    7     2   11   12    1     2  0.181818  12.0
#
#              WCD  WFR  ATAF  LCA       LCD  CSB      CSBS      ACDF
# 491690  0.000000    0   0.0    0  0.000000    0  0.000000  0.000000
# 608293  0.000000    0   0.0    0  0.000000    0  0.000000  0.000000
# 690245  0.000000    0   0.0    0  0.000000    0  0.000000  0.000000
# 772200  0.000000    0   0.0    0  0.000000    0  0.000000  0.000000
# 854155  0.000000   10  12.0   12  1.333333   12  0.571429  1.333333
# 936110  1.333333   21   1.0    2  0.181818   14  0.666667  0.757576
