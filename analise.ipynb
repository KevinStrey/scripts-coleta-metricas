# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', 30)

# %%
evometrics_df = pd.read_csv("results/evometrics.csv")

# %%
evometrics_df[['file', 'method']].head()
# Out:
#                                                                                                                                             file  \
# 0  repo1/dsf-gdb/org.eclipse.cdt.dsf.gdb.multicorevisualizer.ui/src/org/eclipse/cdt/dsf/gdb/multicorevisualizer/internal/ui/model/VisualizerCore
# 1                                                         repo1/core/org.eclipse.cdt.core.tests/suite/org/eclipse/cdt/core/testplugin/CModelMock
# 2                                 repo1/core/org.eclipse.cdt.core/parser/org/eclipse/cdt/core/dom/ast/cpp/ICPPClassTemplatePartialSpecialization
# 3                                        repo1/core/org.eclipse.cdt.core/parser/org/eclipse/cdt/internal/core/dom/parser/cpp/CPPFunctionTemplate
# 4                                       repo1/dsf-gdb/org.eclipse.cdt.dsf.gdb/src/org/eclipse/cdt/dsf/gdb/service/extensions/GDBExpressions_HEAD
#
#                            method
# 0                        getCPU()
# 1                     getParent()
# ...

# %%
evometrics_df[evometrics_df['method'] == 'getSkipBuild()'].to_csv("results/evometrics_getSkipBuild.csv", index=False)

# %%
evometrics_df[evometrics_df['method'] == 'getSkipBuild()']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 evometrics_df[evometrics_df['method'] == 'getSkipBuild()']
#
# NameError: name 'evometrics_df' is not defined

# %%
evometrics_df[evometrics_df['method'] == 'setupSkipBuild()'].to_csv("results/evometrics_setupSkipBuild.csv", index=False)
